# %%
import ModuloCH
from ModuloCH import *
dir(ModuloCH)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'cahn_hilliard_DG_EQ',
#  'cahn_hilliard_DG_EQ_test',
#  'cahn_hilliard_FEM_EQ',
#  'cahn_hilliard_FEM_Eyre']

# %%
cahn_hilliard_FEM_Eyre.test()
# Out:
# max = 0.009999
# min = -0.009998
# mass = -0.000077
# mass = -0.000077
# E = 0.9999923812896785
# mass = -0.000077
# E = 0.9999870401257486
# mass = -0.000077
# E = 0.9999790239835901
# mass = -0.000077
# E = 0.9999638276985909
# mass = -0.000077
# E = 0.999934879407751
# mass = -0.000077
# E = 0.9998793740960296
# mass = -0.000077
# E = 0.9997721011678151
# mass = -0.000077
# E = 0.9995632566295632
# mass = -0.000077
# E = 0.999154192141195
# mass = -0.000077
# E = 0.9983493055619838
# mass = -0.000077
# E = 0.9967614695990608
# mass = -0.000077
# E = 0.993630058364
# mass = -0.000077
# E = 0.9874870238973995
# mass = -0.000077
# E = 0.9756068574971603
# mass = -0.000077
# E = 0.9533234508007805
# mass = -0.000077
# E = 0.9138838026912492
# mass = -0.000077
# E = 0.8505419416490928
# mass = -0.000077
# E = 0.7618212466017003
# mass = -0.000077
# E = 0.6555887212435094
# mass = -0.000077
# E = 0.5467305700929492
# mass = -0.000077
# E = 0.45007092059629017
# mass = -0.000077
# ...

# %% [markdown]
# Observemos que EQ pone de manifiesto la no existencia de un principio del máximo para la ecuación de Cahn-Hilliard:

# %%
cahn_hilliard_FEM_EQ.test()
# Out:
# max = 0.009999
# min = -0.009996
# mass = 0.000053
# Iteraciones:
# mass = 0.000053
# E = 1.2500028562126055
# mass = 0.000053
# E = 1.249927847036613
# mass = 0.000053
# E = 1.2466612719684385
# mass = 0.000053
# E = 1.1505831260712691
# mass = 0.000053
# E = 0.8750998340532187
# mass = 0.000053
# E = 0.7133866091278306
# mass = 0.000053
# E = 0.6320885762633639
# mass = 0.000053
# E = 0.5807463236179864
# mass = 0.000053
# E = 0.531388058978256
# mass = 0.000053
# E = 0.4931073096377103
# mass = 0.000053
# E = 0.45687310818401317
# mass = 0.000053
# E = 0.42538563977104416
# mass = 0.000053
# E = 0.3941431664884143
# mass = 0.000053
# E = 0.37141204594376254
# mass = 0.000053
# E = 0.3432633527916835
# mass = 0.000053
# E = 0.32096103077152577
# mass = 0.000053
# E = 0.29952018125920815
# mass = 0.000053
# E = 0.27868799750238055
# mass = 0.000053
# E = 0.25656210995451173
# mass = 0.000053
# E = 0.24001805042383909
# mass = 0.000053
# E = 0.22214303612855926
# mass = 0.000053
# ...
